# %%
import pandas as pd
from openai import OpenAI
from data_analysis import get_clean_data
import mplfinance as mpf

df_all = get_clean_data()
print(type(df_all))
# Out:
# <class 'dict'>

# %%
df_nvda = get_clean_data()['nvda']
print(type(df_nvda))

print(df_nvda.index)
print(df_nvda)

df_amzn = get_clean_data()['amzn']

# df_nvda['company_name']
print(df_nvda.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df_nvda = get_clean_data()['nvda']
#       2 print(type(df_nvda))
#       4 print(df_nvda.index)
#
# NameError: name 'get_clean_data' is not defined

# %%
df_nvda
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02    4.894500    4.987500    4.862500    4.983750    4.930221
# 2018-01-03    5.102500    5.342500    5.093750    5.311750    5.254698
# 2018-01-04    5.394000    5.451250    5.317250    5.339750    5.282397
# 2018-01-05    5.354750    5.422750    5.277000    5.385000    5.327161
# 2018-01-08    5.510000    5.625000    5.464500    5.550000    5.490389
# ...                ...         ...         ...         ...         ...
# 2024-10-16  133.979996  136.619995  131.580002  135.720001  135.720001
# 2024-10-17  139.339996  140.889999  136.869995  136.929993  136.929993
# 2024-10-18  138.669998  138.899994  137.279999  138.000000  138.000000
# 2024-10-21  138.130005  143.710007  138.000000  143.710007  143.710007
# 2024-10-22  142.919998  144.419998  141.779999  143.589996  143.589996
#
#                Volume company_name
# Date
# 2018-01-02  355616000       Nvidia
# ...

# %%
print(type(df_all))
print(type(df_nvda))

for key in df_all.keys():
    print(key)

print(df_nvda.items())
print(df_nvda.size)
df_nvda
df_amzn
#print(df_all.head())
# Out:
# <class 'dict'>
# <class 'pandas.core.frame.DataFrame'>
# nvda
# tsla
# amzn
# msft
# cost
# gme
# pfe
# lly
# <generator object DataFrame.items at 0x140f56260>
# 11991
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2018-01-02   58.599998   59.500000   58.525501   59.450500   59.450500
# 2018-01-03   59.415001   60.274502   59.415001   60.209999   60.209999
# 2018-01-04   60.250000   60.793499   60.233002   60.479500   60.479500
# 2018-01-05   60.875500   61.457001   60.500000   61.457001   61.457001
# 2018-01-08   61.799999   62.653999   61.601501   62.343498   62.343498
# ...                ...         ...         ...         ...         ...
# 2024-10-16  187.050003  187.779999  185.610001  186.889999  186.889999
# 2024-10-17  188.220001  188.940002  186.000000  187.529999  187.529999
# 2024-10-18  187.149994  190.740005  186.279999  188.990005  188.990005
# 2024-10-21  188.050003  189.460007  186.399994  189.070007  189.070007
# ...

# %%
from data_analysis import get_description

description_dict = get_description()
description_dict
# Out:
# {'nvda':               Open         High          Low        Close    Adj Close  \
#  count  1713.000000  1713.000000  1713.000000  1713.000000  1713.000000
#  mean     25.821331    26.310198    25.299084    25.830662    25.801825
#  std      30.874512    31.468483    30.197902    30.866736    30.874650
#  min       3.162250     3.249500     3.111500     3.177000     3.151646
#  25%       6.184750     6.258500     6.086750     6.171250     6.124423
#  50%      14.157000    14.354750    13.863500    14.160000    14.135490
#  75%      27.375000    28.000000    27.101999    27.579000    27.560066
#  max     142.919998   144.419998   141.779999   143.710007   143.710007
#
#               Volume
#  count  1.713000e+03
#  mean   4.697213e+08
#  std    2.093899e+08
#  min    9.788400e+07
#  25%    3.251240e+08
#  50%    4.333300e+08
#  75%    5.696850e+08
#  max    2.511528e+09  ,
#  'tsla':               Open         High          Low        Close    Adj Close  \
# ...

# %%
# Sample data for a few days
data = {
    'Date': ['2023-10-20', '2023-10-23', '2023-10-24', '2023-10-25', '2023-10-26'],
    'Open': [120.5, 121.5, 122.0, 121.8, 123.0],
    'High': [121.0, 123.0, 123.5, 122.5, 124.0],
    'Low': [119.8, 120.5, 121.2, 120.8, 122.0],
    'Close': [120.8, 122.5, 122.2, 121.5, 123.5],
    'Volume': [1500, 2200, 1800, 1300, 2100]
}

# Convert the data into a DataFrame
df = pd.DataFrame(data)
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace=True)

# Plotting the candlestick chart
mpf.plot(df, type='candle', style='charles', title='Candlestick Chart', ylabel='Price', volume=True)
# Out:
#              Open   High    Low  Close  Volume
# Date
# 2023-10-20  120.5  121.0  119.8  120.8    1500
# 2023-10-23  121.5  123.0  120.5  122.5    2200
# 2023-10-24  122.0  123.5  121.2  122.2    1800
# 2023-10-25  121.8  122.5  120.8  121.5    1300
# 2023-10-26  123.0  124.0  122.0  123.5    2100

# %%
#df_nvda['Date'] = pd.to_datetime(df_nvda['Date'])
mpf.plot(df_nvda, type='candle', style='charles', title='Candlestick Chart for NVDA', ylabel='Price', volume=True)

# Plotting the candlestick chart
#mpf.plot(df_nvda, type='candle', style='charles', title='Candlestick Chart', ylabel='Price', volume=True)
# Out:
# /Users/neo_chara/Desktop/Projects/Stock-Watch/sw_venv/lib/python3.10/site-packages/mplfinance/_arg_validators.py:84: UserWarning:
#
# ...
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
# ...
#   warnings.warn('\n\n ================================================================= '+

# %%
mpf.plot(df_nvda['Date'], type='candle', style='charles', title='Candlestick Chart', ylabel='Price', volume=True)

# %%
STOCK_LIST =  ['NVDA', 'TSLA', 'AMZN', 'MSFT', 'COST']

stocks_dfs_dict = {}

for symbol in STOCK_LIST:
    file_name = f"{symbol.lower()}_stock.csv"
    path_csv = f"data/{file_name}"
    stocks_dfs_dict[f"{symbol.lower()}"] = pd.read_csv(path_csv,index_col='Date')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 8
#       6 file_name = f"{symbol.lower()}_stock.csv"
#       7 path_csv = f"data/{file_name}"
# ----> 8 stocks_dfs_dict[f"{symbol.lower()}"] = pd.read_csv(path_csv,index_col='Date')
#
# ...

# %%
type(stocks_dfs_dict)
stocks_dfs_dict["nvda"].describe()
